# %% [markdown]
# ## 2017_KS_cleaner_code

# %% [markdown]
# Due to the large size of the Kickstarter (KS) Datasets (up to 564 csv files / 10.3gb per year) I wrote some code to process the KS data one year at a time. This code will process KS data from 2017.

# %% [markdown]
# ### IF YOU ARE READING THIS FROM GITHUB PLEASE NOTE THAT RUNNING CELL [2] WILL NOT WORK UNTIL I FIND A WAY TO HOST THE ~28.4 GIGABYTES OF KS DATASETS

# %%
# Imports
import numpy as np
import pandas as pd
import glob #glob allows us to easily concatenate multiple .csvs in one folder

# %%
# Concatenating 2017 KS data with glob
path = r'D:\DSI-D\projects\project_6\Data\2017_KS'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
# EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2114333 entries, 0 to 2114332
# Data columns (total 37 columns):
# backers_count               int64
# blurb                       object
# category                    object
# converted_pledged_amount    float64
# country                     object
# created_at                  int64
# creator                     object
# currency                    object
# currency_symbol             object
# currency_trailing_code      bool
# current_currency            object
# deadline                    int64
# disable_communication       bool
# friends                     object
# fx_rate                     float64
# goal                        float64
# id                          int64
# is_backing                  object
# is_starrable                object
# is_starred                  object
# launched_at                 int64
# location                    object
# name                        object
# permissions                 object
# photo                       object
# pledged                     float64
# profile                     object
# slug                        object
# source_url                  object
# spotlight                   bool
# staff_pick                  bool
# state                       object
# state_changed_at            int64
# static_usd_rate             float64
# urls                        object
# usd_pledged                 float64
# usd_type                    object
# dtypes: bool(4), float64(6), int64(6), object(21)
# memory usage: 540.4+ MB

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             12  Debauchery, laughter, violence and politics. W...
# 1             40  Bring a touring character education play about...
# 2             57  1984. An IRA bomb explodes at the Grand Hotel....
# 3            114  Zoe is a teenage girl growing up in a deeply d...
# 4             31  Theaterprojekt 12. Kl. Waldorfschule Essen. 2 ...
#
#                                             category  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...
# 1  {"urls":{"web":{"discover":"http://www.kicksta...
# 2  {"urls":{"web":{"discover":"http://www.kicksta...
# 3  {"urls":{"web":{"discover":"http://www.kicksta...
# 4  {"urls":{"web":{"discover":"http://www.kicksta...
#
#    converted_pledged_amount country  created_at  \
# 0                       NaN      GB  1431610619
# 1                       NaN      US  1402512498
# 2                       NaN      GB  1408884944
# 3                       NaN      GB  1406837195
# 4                       NaN      DE  1467313927
#
#                                              creator currency currency_symbol  \
# 0  {"urls":{"web":{"user":"https://www.kickstarte...      GBP               £
# 1  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 2  {"urls":{"web":{"user":"https://www.kickstarte...      GBP               £
# 3  {"urls":{"web":{"user":"https://www.kickstarte...      GBP               £
# 4  {"urls":{"web":{"user":"https://www.kickstarte...      EUR               €
#
#    currency_trailing_code  ...  \
# 0                   False  ...
# 1                    True  ...
# 2                   False  ...
# 3                   False  ...
# 4                   False  ...
#
#                                                 slug  \
# 0        royal-holloways-drama-society-presents-posh
# 1                                kylie-for-president
# 2  the-bombing-of-the-grand-hotel-a-compelling-ne...
# 3                                            child-z
# 4                                fausthier-und-jetzt
#
#                                           source_url  spotlight staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...       True      False
# 1  https://www.kickstarter.com/discover/categorie...       True      False
# 2  https://www.kickstarter.com/discover/categorie...       True      False
# 3  https://www.kickstarter.com/discover/categorie...       True      False
# 4  https://www.kickstarter.com/discover/categorie...       True      False
#
#         state  state_changed_at  static_usd_rate  \
# 0  successful        1433113212         1.572673
# 1  successful        1405915140         1.000000
# 2  successful        1411771384         1.658939
# 3  successful        1415191920         1.618854
# 4  successful        1472936230         1.113958
#
#                                                 urls  usd_pledged usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...   379.014248      NaN
# 1  {"web":{"project":"https://www.kickstarter.com...  3530.000000      NaN
# 2  {"web":{"project":"https://www.kickstarter.com...  5053.127524      NaN
# 3  {"web":{"project":"https://www.kickstarter.com...  7357.690612      NaN
# 4  {"web":{"project":"https://www.kickstarter.com...  5012.810505      NaN
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#          backers_count                                              blurb  \
# 2114328             10  Colorful and fresh, one-of-kind paintings with...
# 2114329             44  Get your hands on some wonderful whales! Brand...
# 2114330             20  Help produce one of my more popular designs as...
# 2114331            209  The Black Prism Oracle is a 13 card Oracle dec...
# 2114332            211  This standard poker deck features 52 original ...
#
#                                                   category  \
# 2114328  {"urls":{"web":{"discover":"http://www.kicksta...
# 2114329  {"urls":{"web":{"discover":"http://www.kicksta...
# 2114330  {"urls":{"web":{"discover":"http://www.kicksta...
# 2114331  {"urls":{"web":{"discover":"http://www.kicksta...
# 2114332  {"urls":{"web":{"discover":"http://www.kicksta...
#
#          converted_pledged_amount country  created_at  \
# 2114328                     587.0      DK  1491306475
# 2114329                     670.0      GB  1490201346
# 2114330                     289.0      US  1490077832
# 2114331                    6026.0      US  1490250844
# 2114332                    6216.0      US  1490138399
#
#                                                    creator currency  \
# 2114328  {"urls":{"web":{"user":"https://www.kickstarte...      DKK
# 2114329  {"urls":{"web":{"user":"https://www.kickstarte...      GBP
# 2114330  {"urls":{"web":{"user":"https://www.kickstarte...      USD
# 2114331  {"urls":{"web":{"user":"https://www.kickstarte...      USD
# 2114332  {"urls":{"web":{"user":"https://www.kickstarte...      USD
#
#         currency_symbol  currency_trailing_code  ...  \
# 2114328              kr                    True  ...
# 2114329               £                   False  ...
# 2114330               $                    True  ...
# 2114331               $                    True  ...
# 2114332               $                    True  ...
#
#                                              slug  \
# 2114328                          a-piece-of-earth
# 2114329  save-the-whales-enamel-pins-1-hit-wonder
# 2114330                        diver-down-sticker
# 2114331                    the-black-prism-oracle
# 2114332       obscure-movie-monster-playing-cards
#
#                                                 source_url  spotlight  \
# 2114328  https://www.kickstarter.com/discover/categorie...       True
# 2114329  https://www.kickstarter.com/discover/categorie...       True
# 2114330  https://www.kickstarter.com/discover/categorie...       True
# 2114331  https://www.kickstarter.com/discover/categorie...       True
# 2114332  https://www.kickstarter.com/discover/categorie...       True
#
#         staff_pick       state  state_changed_at  static_usd_rate  \
# 2114328      False  successful        1492388060         0.143583
# 2114329      False  successful        1490809687         1.236575
# 2114330      False  successful        1492810003         1.000000
# 2114331      False  successful        1492992002         1.000000
# 2114332      False  successful        1492966831         1.000000
#
#                                                       urls  usd_pledged  \
# 2114328  {"web":{"project":"https://www.kickstarter.com...   590.844457
# 2114329  {"web":{"project":"https://www.kickstarter.com...   667.750732
# 2114330  {"web":{"project":"https://www.kickstarter.com...   289.000000
# 2114331  {"web":{"project":"https://www.kickstarter.com...  6026.000000
# 2114332  {"web":{"project":"https://www.kickstarter.com...  6216.000000
#
#          usd_type
# 2114328  domestic
# 2114329  domestic
# 2114330  domestic
# 2114331  domestic
# 2114332  domestic
#
# [5 rows x 37 columns]

# %%
# Dropping duplicates to cut down on rows
df.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251571 entries, 0 to 2113853
# Data columns (total 37 columns):
# backers_count               251571 non-null int64
# blurb                       251561 non-null object
# category                    251571 non-null object
# converted_pledged_amount    71631 non-null float64
# country                     251571 non-null object
# created_at                  251571 non-null int64
# creator                     251571 non-null object
# currency                    251571 non-null object
# currency_symbol             251571 non-null object
# currency_trailing_code      251571 non-null bool
# current_currency            71631 non-null object
# deadline                    251571 non-null int64
# disable_communication       251571 non-null bool
# friends                     1007 non-null object
# fx_rate                     24776 non-null float64
# goal                        251571 non-null float64
# id                          251571 non-null int64
# is_backing                  1007 non-null object
# is_starrable                99329 non-null object
# is_starred                  1007 non-null object
# launched_at                 251571 non-null int64
# location                    250502 non-null object
# name                        251570 non-null object
# permissions                 1007 non-null object
# photo                       251571 non-null object
# pledged                     251571 non-null float64
# profile                     251571 non-null object
# slug                        251571 non-null object
# source_url                  251571 non-null object
# spotlight                   251571 non-null bool
# staff_pick                  251571 non-null bool
# state                       251571 non-null object
# state_changed_at            251571 non-null int64
# static_usd_rate             251571 non-null float64
# urls                        251571 non-null object
# usd_pledged                 251571 non-null float64
# usd_type                    71194 non-null object
# dtypes: bool(4), float64(6), int64(6), object(21)
# memory usage: 66.2+ MB

# %%
# Creating a dataframe of only boardgame KS projects
df = df.loc[df['category'] == '{"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}},"color":51627,"parent_id":12,"name":"Tabletop Games","id":34,"position":6,"slug":"games/tabletop games"}']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8609 entries, 175696 to 1253377
# Data columns (total 37 columns):
# backers_count               8609 non-null int64
# blurb                       8609 non-null object
# category                    8609 non-null object
# converted_pledged_amount    2084 non-null float64
# country                     8609 non-null object
# created_at                  8609 non-null int64
# creator                     8609 non-null object
# currency                    8609 non-null object
# currency_symbol             8609 non-null object
# currency_trailing_code      8609 non-null bool
# current_currency            2084 non-null object
# deadline                    8609 non-null int64
# disable_communication       8609 non-null bool
# friends                     541 non-null object
# fx_rate                     184 non-null float64
# goal                        8609 non-null float64
# id                          8609 non-null int64
# is_backing                  541 non-null object
# is_starrable                2792 non-null object
# is_starred                  541 non-null object
# launched_at                 8609 non-null int64
# location                    8604 non-null object
# name                        8609 non-null object
# permissions                 541 non-null object
# photo                       8609 non-null object
# pledged                     8609 non-null float64
# profile                     8609 non-null object
# slug                        8609 non-null object
# source_url                  8609 non-null object
# spotlight                   8609 non-null bool
# staff_pick                  8609 non-null bool
# state                       8609 non-null object
# state_changed_at            8609 non-null int64
# static_usd_rate             8609 non-null float64
# urls                        8609 non-null object
# usd_pledged                 8609 non-null float64
# usd_type                    1971 non-null object
# dtypes: bool(4), float64(6), int64(6), object(21)
# memory usage: 2.3+ MB

# %%
# Saving the cleaned 2017 .csv
df.to_csv("KS_Data/2017_KS_cleaned.csv", index=False)
