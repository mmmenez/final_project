# %% [markdown]
# ## 2016_KS_cleaner_code

# %% [markdown]
# Due to the large size of the Kickstarter (KS) Datasets (up to 564 csv files / 10.3gb per year) I wrote some code to process the KS data one year at a time. This code will process KS data from 2016.

# %% [markdown]
# ### IF YOU ARE READING THIS FROM GITHUB PLEASE NOTE THAT RUNNING CELL [2] WILL NOT WORK UNTIL I FIND A WAY TO HOST THE ~28.4 GIGABYTES OF KS DATASETS

# %%
# imports
import numpy as np
import pandas as pd
import glob #glob allows us to easily concatenate multiple .csvs in one folder

# %%
# Concatenating 2016 KS data with glob
path = r'D:\DSI-D\projects\project_6\Data\2016_KS'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
# EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1757505 entries, 0 to 1757504
# Data columns (total 35 columns):
# backers_count               int64
# blurb                       object
# category                    object
# country                     object
# created_at                  int64
# creator                     object
# currency                    object
# currency_symbol             object
# currency_trailing_code      bool
# deadline                    int64
# disable_communication       bool
# friends                     object
# goal                        float64
# id                          int64
# is_backing                  object
# is_starred                  object
# last_update_published_at    float64
# launched_at                 int64
# location                    object
# name                        object
# permissions                 object
# photo                       object
# pledged                     float64
# profile                     object
# slug                        object
# source_url                  object
# spotlight                   bool
# staff_pick                  bool
# state                       object
# state_changed_at            int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                        object
# usd_pledged                 float64
# dtypes: bool(4), float64(7), int64(6), object(18)
# memory usage: 422.4+ MB

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  Exploring paint and its place in a digital world.
# 1              2  Mike Fassio wants a side-by-side photo of me a...
# 2              0  I need your help to get a nice graphics tablet...
# 3              0  I want to create a Nature Photograph Series of...
# 4              1  I want to bring colour to the world in my own ...
#
#                                             category country  created_at  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...      US  1426632761
# 1  {"urls":{"web":{"discover":"http://www.kicksta...      US  1405105835
# 2  {"urls":{"web":{"discover":"http://www.kicksta...      US  1406681308
# 3  {"urls":{"web":{"discover":"http://www.kicksta...      US  1431120560
# 4  {"urls":{"web":{"discover":"http://www.kicksta...      GB  1422798827
#
#                                              creator currency currency_symbol  \
# 0  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 1  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 2  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 3  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 4  {"urls":{"web":{"user":"https://www.kickstarte...      GBP               £
#
#    currency_trailing_code    deadline  ...  \
# 0                    True  1430435520  ...
# 1                    True  1406426107  ...
# 2                    True  1409329753  ...
# 3                    True  1433088551  ...
# 4                   False  1425847922  ...
#
#                                           source_url spotlight  staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...     False       False
# 1  https://www.kickstarter.com/discover/categorie...     False       False
# 2  https://www.kickstarter.com/discover/categorie...     False       False
# 3  https://www.kickstarter.com/discover/categorie...     False       False
# 4  https://www.kickstarter.com/discover/categorie...     False       False
#
#     state state_changed_at static_usd_rate  unread_messages_count  \
# 0  failed       1430435520         1.00000                    NaN
# 1  failed       1406426107         1.00000                    NaN
# 2  failed       1409329810         1.00000                    NaN
# 3  failed       1433088553         1.00000                    NaN
# 4  failed       1425847924         1.52011                    NaN
#
#    unseen_activity_count                                               urls  \
# 0                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 1                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 2                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 3                    NaN  {"web":{"project":"https://www.kickstarter.com...
# 4                    NaN  {"web":{"project":"https://www.kickstarter.com...
#
#   usd_pledged
# 0    25.00000
# 1     6.00000
# 2     0.00000
# 3     0.00000
# 4     1.52011
#
# [5 rows x 35 columns]

# %%
df.tail()
# Out:
#          backers_count                                              blurb  \
# 1757500              8  "Rashawn Thompson", a Chicago Performer, wants...
# 1757501             10      Burlesque inspired, All female musical review
# 1757502              5  A powerful live musical of true stories of wom...
# 1757503              0  The Return of Neverland is an exciting new mus...
# 1757504              3  Help make our music theatre show a smash hit a...
#
#                                                   category country  \
# 1757500  {"urls":{"web":{"discover":"http://www.kicksta...      US
# 1757501  {"urls":{"web":{"discover":"http://www.kicksta...      US
# 1757502  {"urls":{"web":{"discover":"http://www.kicksta...      US
# 1757503  {"urls":{"web":{"discover":"http://www.kicksta...      GB
# 1757504  {"urls":{"web":{"discover":"http://www.kicksta...      GB
#
#          created_at                                            creator  \
# 1757500  1446328456  {"urls":{"web":{"user":"https://www.kickstarte...
# 1757501  1367464558  {"urls":{"web":{"user":"https://www.kickstarte...
# 1757502  1419909031  {"urls":{"web":{"user":"https://www.kickstarte...
# 1757503  1447973800  {"urls":{"web":{"user":"https://www.kickstarte...
# 1757504  1447350633  {"urls":{"web":{"user":"https://www.kickstarte...
#
#         currency currency_symbol  currency_trailing_code    deadline  ...  \
# 1757500      USD               $                    True  1451712600  ...
# 1757501      USD               $                    True  1429329600  ...
# 1757502      USD               $                    True  1425698340  ...
# 1757503      GBP               £                   False  1453235971  ...
# 1757504      GBP               £                   False  1451566500  ...
#
#                                                 source_url spotlight  \
# 1757500  https://www.kickstarter.com/discover/categorie...     False
# 1757501  https://www.kickstarter.com/discover/categorie...     False
# 1757502  https://www.kickstarter.com/discover/categorie...     False
# 1757503  https://www.kickstarter.com/discover/categorie...     False
# 1757504  https://www.kickstarter.com/discover/categorie...     False
#
#          staff_pick   state state_changed_at static_usd_rate  \
# 1757500       False  failed       1451712601        1.000000
# 1757501       False  failed       1429329612        1.000000
# 1757502       False  failed       1425698341        1.000000
# 1757503       False  failed       1453235972        1.489312
# 1757504       False  failed       1451566500        1.521336
#
#          unread_messages_count  unseen_activity_count  \
# 1757500                    NaN                    NaN
# 1757501                    NaN                    NaN
# 1757502                    NaN                    NaN
# 1757503                    NaN                    NaN
# 1757504                    NaN                    NaN
#
#                                                       urls usd_pledged
# 1757500  {"web":{"project":"https://www.kickstarter.com...  340.000000
# 1757501  {"web":{"project":"https://www.kickstarter.com...  270.000000
# 1757502  {"web":{"project":"https://www.kickstarter.com...   80.000000
# 1757503  {"web":{"project":"https://www.kickstarter.com...    0.000000
# 1757504  {"web":{"project":"https://www.kickstarter.com...  304.191129
#
# [5 rows x 35 columns]

# %%
# Dropping duplicates to cut down on rows
df.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200100 entries, 0 to 1756902
# Data columns (total 35 columns):
# backers_count               200100 non-null int64
# blurb                       200093 non-null object
# category                    200100 non-null object
# country                     200100 non-null object
# created_at                  200100 non-null int64
# creator                     200100 non-null object
# currency                    200100 non-null object
# currency_symbol             200100 non-null object
# currency_trailing_code      200100 non-null bool
# deadline                    200100 non-null int64
# disable_communication       200100 non-null bool
# friends                     493 non-null object
# goal                        200100 non-null float64
# id                          200100 non-null int64
# is_backing                  493 non-null object
# is_starred                  493 non-null object
# last_update_published_at    0 non-null float64
# launched_at                 200100 non-null int64
# location                    199308 non-null object
# name                        200099 non-null object
# permissions                 106 non-null object
# photo                       200100 non-null object
# pledged                     200100 non-null float64
# profile                     200100 non-null object
# slug                        200100 non-null object
# source_url                  200100 non-null object
# spotlight                   200100 non-null bool
# staff_pick                  200100 non-null bool
# state                       200100 non-null object
# state_changed_at            200100 non-null int64
# static_usd_rate             200100 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        200100 non-null object
# usd_pledged                 200100 non-null float64
# dtypes: bool(4), float64(7), int64(6), object(18)
# memory usage: 49.6+ MB

# %%
# Creating a dataframe of only boardgame KS projects
df = df.loc[df['category'] == '{"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}},"color":51627,"parent_id":12,"name":"Tabletop Games","id":34,"position":6,"slug":"games/tabletop games"}']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6701 entries, 543139 to 943143
# Data columns (total 35 columns):
# backers_count               6701 non-null int64
# blurb                       6701 non-null object
# category                    6701 non-null object
# country                     6701 non-null object
# created_at                  6701 non-null int64
# creator                     6701 non-null object
# currency                    6701 non-null object
# currency_symbol             6701 non-null object
# currency_trailing_code      6701 non-null bool
# deadline                    6701 non-null int64
# disable_communication       6701 non-null bool
# friends                     186 non-null object
# goal                        6701 non-null float64
# id                          6701 non-null int64
# is_backing                  186 non-null object
# is_starred                  186 non-null object
# last_update_published_at    0 non-null float64
# launched_at                 6701 non-null int64
# location                    6696 non-null object
# name                        6701 non-null object
# permissions                 28 non-null object
# photo                       6701 non-null object
# pledged                     6701 non-null float64
# profile                     6701 non-null object
# slug                        6701 non-null object
# source_url                  6701 non-null object
# spotlight                   6701 non-null bool
# staff_pick                  6701 non-null bool
# state                       6701 non-null object
# state_changed_at            6701 non-null int64
# static_usd_rate             6701 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        6701 non-null object
# usd_pledged                 6701 non-null float64
# dtypes: bool(4), float64(7), int64(6), object(18)
# memory usage: 1.7+ MB

# %%
# Saving the cleaned 2016 .csv
df.to_csv("KS_data/2016_KS_cleaned.csv", index = False)
