# %%
import numpy as np
import pandas as pd
import glob

# %%
path = r'D:\DSI-D\projects\project_6\Data\2019_KS'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # Remove the CWD from sys.path while we load stuff.

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524170 entries, 0 to 2524169
# Data columns (total 40 columns):
# backers_count               int64
# blurb                       object
# category                    object
# converted_pledged_amount    int64
# country                     object
# country_displayable_name    object
# created_at                  int64
# creator                     object
# currency                    object
# currency_symbol             object
# currency_trailing_code      bool
# current_currency            object
# deadline                    int64
# disable_communication       bool
# friends                     object
# fx_rate                     float64
# goal                        float64
# id                          int64
# is_backing                  object
# is_starrable                bool
# is_starred                  object
# launched_at                 int64
# location                    object
# name                        object
# permissions                 object
# photo                       object
# pledged                     float64
# profile                     object
# slug                        object
# source_url                  object
# spotlight                   bool
# staff_pick                  bool
# state                       object
# state_changed_at            int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                        object
# usd_pledged                 float64
# usd_type                    object
# dtypes: bool(5), float64(7), int64(7), object(21)
# memory usage: 686.1+ MB

# %%
frame.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 218155 entries, 0 to 2524013
# Data columns (total 40 columns):
# backers_count               218155 non-null int64
# blurb                       218150 non-null object
# category                    218155 non-null object
# converted_pledged_amount    218155 non-null int64
# country                     218155 non-null object
# country_displayable_name    56243 non-null object
# created_at                  218155 non-null int64
# creator                     218155 non-null object
# currency                    218155 non-null object
# currency_symbol             218155 non-null object
# currency_trailing_code      218155 non-null bool
# current_currency            218155 non-null object
# deadline                    218155 non-null int64
# disable_communication       218155 non-null bool
# friends                     834 non-null object
# fx_rate                     218155 non-null float64
# goal                        218155 non-null float64
# id                          218155 non-null int64
# is_backing                  834 non-null object
# is_starrable                218155 non-null bool
# is_starred                  834 non-null object
# launched_at                 218155 non-null int64
# location                    217931 non-null object
# name                        218155 non-null object
# permissions                 834 non-null object
# photo                       218155 non-null object
# pledged                     218155 non-null float64
# profile                     218155 non-null object
# slug                        218155 non-null object
# source_url                  218155 non-null object
# spotlight                   218155 non-null bool
# staff_pick                  218155 non-null bool
# state                       218155 non-null object
# state_changed_at            218155 non-null int64
# static_usd_rate             218155 non-null float64
# unread_messages_count       1 non-null float64
# unseen_activity_count       1 non-null float64
# urls                        218155 non-null object
# usd_pledged                 218155 non-null float64
# usd_type                    217201 non-null object
# dtypes: bool(5), float64(7), int64(7), object(21)
# memory usage: 61.0+ MB

# %%
frame.head()
# Out:
#    backers_count                                              blurb  \
# 0            108  In the year 2025, a young man's superintellige...
# 1             37  Replacement Place needs your support to combat...
# 2             27  Pumpkin Spice Love - A Pumpkin Spice 4 Life 30...
# 3            184  Single mama and her 4-year old sail with all-f...
# 4            169  SparKit wishes to produce kit-set Wimshurst Ma...
#
#                                             category  \
# 0  {"id":32,"name":"Shorts","slug":"film & video/...
# 1  {"id":254,"name":"Performances","slug":"dance/...
# 2  {"id":262,"name":"Accessories","slug":"fashion...
# 3  {"id":13,"name":"Journalism","slug":"journalis...
# 4  {"id":334,"name":"DIY Electronics","slug":"tec...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      5265      US                      NaN  1474949898
# 1                      5225      US                      NaN  1425755444
# 2                       362      US                      NaN  1504654576
# 3                     15678      US                      NaN  1440164389
# 4                      8217      NZ                      NaN  1474436782
#
#                                              creator currency currency_symbol  \
# 0  {"id":917453276,"name":"Ryan Turner","slug":"r...      USD               $
# 1  {"id":1584296239,"name":"Patricia Noworol Danc...      USD               $
# 2  {"id":1930804198,"name":"Mandy Robertson","slu...      USD               $
# 3  {"id":1435241906,"name":"Ky Delaney","is_regis...      USD               $
# 4  {"id":266345803,"name":"Luka Phillips","is_reg...      NZD               $
#
#    ...  spotlight staff_pick       state  state_changed_at static_usd_rate  \
# 0  ...       True      False  successful        1477674323        1.000000
# 1  ...       True       True  successful        1431748742        1.000000
# 2  ...       True      False  successful        1506112227        1.000000
# 3  ...       True      False  successful        1446670947        1.000000
# 4  ...       True      False  successful        1486790794        0.699145
#
#    unread_messages_count  unseen_activity_count  \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN
#
#                                                 urls   usd_pledged  \
# 0  {"web":{"project":"https://www.kickstarter.com...   5265.820000
# 1  {"web":{"project":"https://www.kickstarter.com...   5225.000000
# 2  {"web":{"project":"https://www.kickstarter.com...    362.000000
# 3  {"web":{"project":"https://www.kickstarter.com...  15678.000000
# 4  {"web":{"project":"https://www.kickstarter.com...   7978.645365
#
#         usd_type
# 0       domestic
# 1       domestic
# 2       domestic
# 3  international
# 4       domestic
#
# [5 rows x 40 columns]

# %%
df = frame.loc[frame['category'] == '{"id":34,"name":"Tabletop Games","slug":"games/tabletop games","position":6,"parent_id":12,"color":51627,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}}}']

# %%
df.head()
# Out:
#     backers_count                                              blurb  \
# 25           3658  A strategic survival board game in the mutant ...
# 36           1179  Fight mythical Celtic battles with this exciti...
# 49            195  Become a legendary Hero in this multiplayer ca...
# 52             41  BattleMonsters - The game of monstrous pit fig...
# 63             24  We want to complete the Broken Contract Breake...
#
#                                              category  \
# 25  {"id":34,"name":"Tabletop Games","slug":"games...
# 36  {"id":34,"name":"Tabletop Games","slug":"games...
# 49  {"id":34,"name":"Tabletop Games","slug":"games...
# 52  {"id":34,"name":"Tabletop Games","slug":"games...
# 63  {"id":34,"name":"Tabletop Games","slug":"games...
#
#     converted_pledged_amount country country_displayable_name  created_at  \
# 25                    304931      US                      NaN  1525203058
# 36                     77240      US                      NaN  1535033477
# 49                     13362      US                      NaN  1526950706
# 52                      4334      DK                      NaN  1537269796
# 63                       993      US                      NaN  1502229828
#
#                                               creator currency  \
# 25  {"id":1897526369,"name":"Mighty Boards","slug"...      USD
# 36  {"id":2004581878,"name":"Eclipse Editorial","s...      USD
# 49  {"id":6480230,"name":"Jimmy Ellerth","is_regis...      USD
# 52  {"id":1958666096,"name":"Jonas Ballegaard Plas...      DKK
# 63  {"id":401223236,"name":"Nick Baran","is_regist...      USD
#
#    currency_symbol  ...  spotlight staff_pick       state  state_changed_at  \
# 25               $  ...       True       True  successful        1529046003
# 36               $  ...       True       True  successful        1538686800
# 49               $  ...       True      False  successful        1535631644
# 52              kr  ...       True      False  successful        1541613610
# 63               $  ...       True      False  successful        1542844800
#
#    static_usd_rate  unread_messages_count  unseen_activity_count  \
# 25        1.000000                    NaN                    NaN
# 36        1.000000                    NaN                    NaN
# 49        1.000000                    NaN                    NaN
# 52        0.154464                    NaN                    NaN
# 63        1.000000                    NaN                    NaN
#
#                                                  urls    usd_pledged  usd_type
# 25  {"web":{"project":"https://www.kickstarter.com...  304931.290000  domestic
# 36  {"web":{"project":"https://www.kickstarter.com...   77240.000000  domestic
# 49  {"web":{"project":"https://www.kickstarter.com...   13362.500000  domestic
# 52  {"web":{"project":"https://www.kickstarter.com...    4358.775104  domestic
# 63  {"web":{"project":"https://www.kickstarter.com...     993.000000  domestic
#
# [5 rows x 40 columns]

# %%
df.tail()
# Out:
#          backers_count                                              blurb  \
# 2385391            178  A fantasy post-apocalyptic RPG inspired by Thu...
# 2387142             11  We will be creating a Victorian and steampunk ...
# 2387799             14                          Strategy. Sabotage. Meow.
# 2401759             19  Ten awesome monsters from the world's greatest...
# 2505037              2  Think About It is a card game where you use yo...
#
#                                                   category  \
# 2385391  {"id":34,"name":"Tabletop Games","slug":"games...
# 2387142  {"id":34,"name":"Tabletop Games","slug":"games...
# 2387799  {"id":34,"name":"Tabletop Games","slug":"games...
# 2401759  {"id":34,"name":"Tabletop Games","slug":"games...
# 2505037  {"id":34,"name":"Tabletop Games","slug":"games...
#
#          converted_pledged_amount country country_displayable_name  \
# 2385391                      6879      US                      NaN
# 2387142                       310      US                      NaN
# 2387799                       601      US                      NaN
# 2401759                       747      US                      NaN
# 2505037                         2      US                      NaN
#
#          created_at                                            creator  \
# 2385391  1548512332  {"id":1070557469,"name":"Mike (wrathofzombie) ...
# 2387142  1560733728  {"id":1392188291,"name":"Ben Bernard","slug":"...
# 2387799  1539906108  {"id":585041515,"name":"Shannon Hall","slug":"...
# 2401759  1544638380  {"id":641573961,"name":"Cody Knox","is_registe...
# 2505037  1557248176  {"id":547903594,"name":"William Foster","slug"...
#
#         currency currency_symbol  ...  spotlight staff_pick  state  \
# 2385391      USD               $  ...      False      False   live
# 2387142      USD               $  ...      False      False   live
# 2387799      USD               $  ...      False      False   live
# 2401759      USD               $  ...      False      False   live
# 2505037      USD               $  ...      False      False   live
#
#          state_changed_at static_usd_rate  unread_messages_count  \
# 2385391        1563199463             1.0                    NaN
# 2387142        1561032629             1.0                    NaN
# 2387799        1562774560             1.0                    NaN
# 2401759        1549984314             1.0                    NaN
# 2505037        1557675901             1.0                    NaN
#
#          unseen_activity_count  \
# 2385391                    NaN
# 2387142                    NaN
# 2387799                    NaN
# 2401759                    NaN
# 2505037                    NaN
#
#                                                       urls usd_pledged  \
# 2385391  {"web":{"project":"https://www.kickstarter.com...      6879.0
# 2387142  {"web":{"project":"https://www.kickstarter.com...       310.0
# 2387799  {"web":{"project":"https://www.kickstarter.com...       601.0
# 2401759  {"web":{"project":"https://www.kickstarter.com...       747.0
# 2505037  {"web":{"project":"https://www.kickstarter.com...         2.0
#
#          usd_type
# 2385391  domestic
# 2387142  domestic
# 2387799  domestic
# 2401759  domestic
# 2505037  domestic
#
# [5 rows x 40 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48475 entries, 25 to 2524163
# Data columns (total 40 columns):
# backers_count               48475 non-null int64
# blurb                       48475 non-null object
# category                    48475 non-null object
# converted_pledged_amount    48475 non-null int64
# country                     48475 non-null object
# country_displayable_name    12084 non-null object
# created_at                  48475 non-null int64
# creator                     48475 non-null object
# currency                    48475 non-null object
# currency_symbol             48475 non-null object
# currency_trailing_code      48475 non-null bool
# current_currency            48475 non-null object
# deadline                    48475 non-null int64
# disable_communication       48475 non-null bool
# friends                     1630 non-null object
# fx_rate                     48475 non-null float64
# goal                        48475 non-null float64
# id                          48475 non-null int64
# is_backing                  1630 non-null object
# is_starrable                48475 non-null bool
# is_starred                  1630 non-null object
# launched_at                 48475 non-null int64
# location                    48475 non-null object
# name                        48475 non-null object
# permissions                 1630 non-null object
# photo                       48475 non-null object
# pledged                     48475 non-null float64
# profile                     48475 non-null object
# slug                        48475 non-null object
# source_url                  48475 non-null object
# spotlight                   48475 non-null bool
# staff_pick                  48475 non-null bool
# state                       48475 non-null object
# state_changed_at            48475 non-null int64
# static_usd_rate             48475 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        48475 non-null object
# usd_pledged                 48475 non-null float64
# usd_type                    47633 non-null object
# dtypes: bool(5), float64(7), int64(7), object(21)
# memory usage: 13.5+ MB

# %%
df.dtypes
# Out:
# backers_count                 int64
# blurb                        object
# category                     object
# converted_pledged_amount      int64
# country                      object
# country_displayable_name     object
# created_at                    int64
# creator                      object
# currency                     object
# currency_symbol              object
# currency_trailing_code         bool
# current_currency             object
# deadline                      int64
# disable_communication          bool
# friends                      object
# fx_rate                     float64
# goal                        float64
# id                            int64
# is_backing                   object
# is_starrable                   bool
# is_starred                   object
# launched_at                   int64
# location                     object
# name                         object
# permissions                  object
# photo                        object
# pledged                     float64
# profile                      object
# slug                         object
# source_url                   object
# spotlight                      bool
# staff_pick                     bool
# state                        object
# state_changed_at              int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                         object
# usd_pledged                 float64
# usd_type                     object
# dtype: object

# %%
df.to_csv("KS_Data/2019_KS_cleaned.csv")
