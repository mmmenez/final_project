# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import glob

# %%
KSdf1 = pd.read_csv('2018_KS_cleaned.csv', engine = 'python')

# %%
KSdf2 = pd.read_csv('2019_KS_cleaned.csv', engine = 'python')

# %%
KSdf['name']

# %%
BGGdf['name']

# %%
dfstring = pd.read_csv("2018_KS_cleaned.csv", dtype=str)

# %%
# Combining the KS and BGG datasets
path = r'D:\DSI-D\projects\project_6\Data'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, engine = 'python')
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12230 entries, 0 to 12229
# Data columns (total 41 columns):
# Unnamed: 0                  12230 non-null int64
# backers_count               12230 non-null int64
# blurb                       12230 non-null object
# category                    12230 non-null object
# converted_pledged_amount    12230 non-null int64
# country                     12230 non-null object
# country_displayable_name    1643 non-null object
# created_at                  12230 non-null int64
# creator                     12230 non-null object
# currency                    12230 non-null object
# currency_symbol             12230 non-null object
# currency_trailing_code      12230 non-null bool
# current_currency            12230 non-null object
# deadline                    12230 non-null int64
# disable_communication       12230 non-null bool
# friends                     666 non-null object
# fx_rate                     12230 non-null float64
# goal                        12230 non-null float64
# id                          12230 non-null int64
# is_backing                  666 non-null object
# is_starrable                12230 non-null bool
# is_starred                  666 non-null object
# launched_at                 12230 non-null int64
# location                    12225 non-null object
# name                        12230 non-null object
# permissions                 666 non-null object
# photo                       12230 non-null object
# pledged                     12230 non-null float64
# profile                     12230 non-null object
# slug                        12230 non-null object
# source_url                  8307 non-null object
# spotlight                   12230 non-null bool
# staff_pick                  12230 non-null bool
# state                       12230 non-null object
# state_changed_at            12230 non-null int64
# static_usd_rate             12230 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        12230 non-null object
# usd_pledged                 12230 non-null float64
# usd_type                    11530 non-null object
# dtypes: bool(5), float64(7), int64(8), object(21)
# memory usage: 3.4+ MB

# %%
# Making sure that there are no duplicates  (there may have been some overlap for KS projects that went for both 2017 and 2018 (eg. Dec-Jan))
frame.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12229 entries, 0 to 12229
# Data columns (total 41 columns):
# Unnamed: 0                  12229 non-null int64
# backers_count               12229 non-null int64
# blurb                       12229 non-null object
# category                    12229 non-null object
# converted_pledged_amount    12229 non-null int64
# country                     12229 non-null object
# country_displayable_name    1643 non-null object
# created_at                  12229 non-null int64
# creator                     12229 non-null object
# currency                    12229 non-null object
# currency_symbol             12229 non-null object
# currency_trailing_code      12229 non-null bool
# current_currency            12229 non-null object
# deadline                    12229 non-null int64
# disable_communication       12229 non-null bool
# friends                     666 non-null object
# fx_rate                     12229 non-null float64
# goal                        12229 non-null float64
# id                          12229 non-null int64
# is_backing                  666 non-null object
# is_starrable                12229 non-null bool
# is_starred                  666 non-null object
# launched_at                 12229 non-null int64
# location                    12224 non-null object
# name                        12229 non-null object
# permissions                 666 non-null object
# photo                       12229 non-null object
# pledged                     12229 non-null float64
# profile                     12229 non-null object
# slug                        12229 non-null object
# source_url                  8306 non-null object
# spotlight                   12229 non-null bool
# staff_pick                  12229 non-null bool
# state                       12229 non-null object
# state_changed_at            12229 non-null int64
# static_usd_rate             12229 non-null float64
# unread_messages_count       0 non-null float64
# unseen_activity_count       0 non-null float64
# urls                        12229 non-null object
# usd_pledged                 12229 non-null float64
# usd_type                    11529 non-null object
# dtypes: bool(5), float64(7), int64(8), object(21)
# memory usage: 3.5+ MB

# %%
frame.head()
# Out:
#    Unnamed: 0  backers_count  \
# 0       12261             62
# 1       12283           1126
# 2       12304            189
# 3       12316             86
# 4       12322            413
#
#                                                blurb  \
# 0  Help "uplift" some of the great 6mm scale mini...
# 1  DemonWars: Reformation is an old-school tablet...
# 2  The popular Yushino iPhone, Android, Facebook ...
# 3  HELLO SWEET POTATOâ„¢â€”A fun way to teach kid...
# 4  Fully cooperative tile-based exploration and r...
#
#                                             category  \
# 0  {"id":34,"name":"Tabletop Games","slug":"games...
# 1  {"id":34,"name":"Tabletop Games","slug":"games...
# 2  {"id":34,"name":"Tabletop Games","slug":"games...
# 3  {"id":34,"name":"Tabletop Games","slug":"games...
# 4  {"id":34,"name":"Tabletop Games","slug":"games...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                      4835      US                      NaN  1396471023
# 1                     88245      US                      NaN  1374080930
# 2                     10460      US                      NaN  1378404565
# 3                     15655      US                      NaN  1376051121
# 4                     32105      US                      NaN  1392516861
#
#                                              creator currency  ... spotlight  \
# 0  {"id":1101721577,"name":"Darkest Star Games","...      USD  ...      True
# 1  {"id":1565757521,"name":"R.A. Salvatore","slug...      USD  ...      True
# 2  {"id":729844106,"name":"Yushino","is_registere...      USD  ...      True
# 3  {"id":84294323,"name":"Barbara Movius","is_reg...      USD  ...      True
# 4  {"id":1299225771,"name":"Dave Schroeder","is_r...      USD  ...      True
#
#    staff_pick       state  state_changed_at  static_usd_rate  \
# 0       False  successful        1399569203              1.0
# 1        True  successful        1377873534              1.0
# 2        True  successful        1381670506              1.0
# 3        True  successful        1382032720              1.0
# 4        True  successful        1400471940              1.0
#
#   unread_messages_count  unseen_activity_count  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
#
#                                                 urls  usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...      4835.00  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...     88245.66  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...     10460.00  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...     15655.00  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...     32105.00  domestic
#
# [5 rows x 41 columns]

# %%
# Making sure no non-boardgame entries made it in
frame = frame.loc[frame['category'] == '{"id":34,"name":"Tabletop Games","slug":"games/tabletop games","position":6,"parent_id":12,"color":51627,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}}}']

# %%
frame.dtypes
# Out:
# Unnamed: 0                    int64
# backers_count                 int64
# blurb                        object
# category                     object
# converted_pledged_amount      int64
# country                      object
# country_displayable_name     object
# created_at                    int64
# creator                      object
# currency                     object
# currency_symbol              object
# currency_trailing_code         bool
# current_currency             object
# deadline                      int64
# disable_communication          bool
# friends                      object
# fx_rate                     float64
# goal                        float64
# id                            int64
# is_backing                   object
# is_starrable                   bool
# is_starred                   object
# launched_at                   int64
# location                     object
# name                         object
# permissions                  object
# photo                        object
# pledged                     float64
# profile                      object
# slug                         object
# source_url                   object
# spotlight                      bool
# staff_pick                     bool
# state                        object
# state_changed_at              int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                         object
# usd_pledged                 float64
# usd_type                     object
# dtype: object

# %%
# Dropping columns that won't be useful
frame.drop(columns = ['currency_symbol', 'currency_trailing_code', 'disable_communication', 'photo', 'unread_messages_count', 'unseen_activity_count', 'Unnamed: 0'])
# Out:
#        backers_count                                              blurb  \
# 0                 62  Help "uplift" some of the great 6mm scale mini...
# 1               1126  DemonWars: Reformation is an old-school tablet...
# 2                189  The popular Yushino iPhone, Android, Facebook ...
# 3                 86  HELLO SWEET POTATOâ„¢â€”A fun way to teach kid...
# 4                413  Fully cooperative tile-based exploration and r...
# ...              ...                                                ...
# 12225            178  A fantasy post-apocalyptic RPG inspired by Thu...
# 12226             11  We will be creating a Victorian and steampunk ...
# 12227             14                          Strategy. Sabotage. Meow.
# 12228             19  Ten awesome monsters from the world's greatest...
# 12229              2  Think About It is a card game where you use yo...
#
#                                                 category  \
# 0      {"id":34,"name":"Tabletop Games","slug":"games...
# 1      {"id":34,"name":"Tabletop Games","slug":"games...
# 2      {"id":34,"name":"Tabletop Games","slug":"games...
# 3      {"id":34,"name":"Tabletop Games","slug":"games...
# 4      {"id":34,"name":"Tabletop Games","slug":"games...
# ...                                                  ...
# 12225  {"id":34,"name":"Tabletop Games","slug":"games...
# 12226  {"id":34,"name":"Tabletop Games","slug":"games...
# 12227  {"id":34,"name":"Tabletop Games","slug":"games...
# 12228  {"id":34,"name":"Tabletop Games","slug":"games...
# 12229  {"id":34,"name":"Tabletop Games","slug":"games...
#
#        converted_pledged_amount country country_displayable_name  created_at  \
# 0                          4835      US                      NaN  1396471023
# 1                         88245      US                      NaN  1374080930
# 2                         10460      US                      NaN  1378404565
# 3                         15655      US                      NaN  1376051121
# 4                         32105      US                      NaN  1392516861
# ...                         ...     ...                      ...         ...
# 12225                      6879      US                      NaN  1548512332
# 12226                       310      US                      NaN  1560733728
# 12227                       601      US                      NaN  1539906108
# 12228                       747      US                      NaN  1544638380
# 12229                         2      US                      NaN  1557248176
#
#                                                  creator currency  \
# 0      {"id":1101721577,"name":"Darkest Star Games","...      USD
# 1      {"id":1565757521,"name":"R.A. Salvatore","slug...      USD
# 2      {"id":729844106,"name":"Yushino","is_registere...      USD
# 3      {"id":84294323,"name":"Barbara Movius","is_reg...      USD
# 4      {"id":1299225771,"name":"Dave Schroeder","is_r...      USD
# ...                                                  ...      ...
# 12225  {"id":1070557469,"name":"Mike (wrathofzombie) ...      USD
# 12226  {"id":1392188291,"name":"Ben Bernard","slug":"...      USD
# 12227  {"id":585041515,"name":"Shannon Hall","slug":"...      USD
# 12228  {"id":641573961,"name":"Cody Knox","is_registe...      USD
# 12229  {"id":547903594,"name":"William Foster","slug"...      USD
#
#       current_currency  ...  \
# 0                  USD  ...
# 1                  USD  ...
# 2                  USD  ...
# 3                  USD  ...
# 4                  USD  ...
# ...                ...  ...
# 12225              USD  ...
# 12226              USD  ...
# 12227              USD  ...
# 12228              USD  ...
# 12229              USD  ...
#
#                                                     slug  \
# 0      darkest-star-games-15mm-scale-dark-star-tanks-and
# 1                                demonwars-reformation-0
# 2                     yushino-is-scrabble-with-numbers-0
# 3                                   hello-sweet-potatotm
# 4               unknown-1-6-player-cooperative-boardgame
# ...                                                  ...
# 12225                 the-barbarians-of-the-ruined-earth
# 12226  gilded-suns-a-victorian-pathfinder-campaign-se...
# 12227                                          cat-fight
# 12228           adorably-deadly-dandd-monster-pin-badges
# 12229                                     think-about-it
#
#                                               source_url  spotlight  \
# 0      https://www.kickstarter.com/discover/categorie...       True
# 1      https://www.kickstarter.com/discover/categorie...       True
# 2      https://www.kickstarter.com/discover/categorie...       True
# 3      https://www.kickstarter.com/discover/categorie...       True
# 4      https://www.kickstarter.com/discover/categorie...       True
# ...                                                  ...        ...
# 12225  https://www.kickstarter.com/discover/categorie...      False
# 12226  https://www.kickstarter.com/discover/categorie...      False
# 12227  https://www.kickstarter.com/discover/categorie...      False
# 12228  https://www.kickstarter.com/discover/categorie...      False
# 12229  https://www.kickstarter.com/discover/categorie...      False
#
#        staff_pick       state state_changed_at  static_usd_rate  \
# 0           False  successful       1399569203              1.0
# 1            True  successful       1377873534              1.0
# 2            True  successful       1381670506              1.0
# 3            True  successful       1382032720              1.0
# 4            True  successful       1400471940              1.0
# ...           ...         ...              ...              ...
# 12225       False        live       1563199463              1.0
# 12226       False        live       1561032629              1.0
# 12227       False        live       1562774560              1.0
# 12228       False        live       1549984314              1.0
# 12229       False        live       1557675901              1.0
#
#                                                     urls  usd_pledged  \
# 0      {"web":{"project":"https://www.kickstarter.com...      4835.00
# 1      {"web":{"project":"https://www.kickstarter.com...     88245.66
# 2      {"web":{"project":"https://www.kickstarter.com...     10460.00
# 3      {"web":{"project":"https://www.kickstarter.com...     15655.00
# 4      {"web":{"project":"https://www.kickstarter.com...     32105.00
# ...                                                  ...          ...
# 12225  {"web":{"project":"https://www.kickstarter.com...      6879.00
# 12226  {"web":{"project":"https://www.kickstarter.com...       310.00
# 12227  {"web":{"project":"https://www.kickstarter.com...       601.00
# 12228  {"web":{"project":"https://www.kickstarter.com...       747.00
# 12229  {"web":{"project":"https://www.kickstarter.com...         2.00
#
#        usd_type
# 0      domestic
# 1      domestic
# 2      domestic
# 3      domestic
# 4      domestic
# ...         ...
# 12225  domestic
# 12226  domestic
# 12227  domestic
# 12228  domestic
# 12229  domestic
#
# [12229 rows x 34 columns]

# %%
frame['name'] = frame['name'].astype("str")

# %%
frame.dtypes
# Out:
# Unnamed: 0                    int64
# backers_count                 int64
# blurb                        object
# category                     object
# converted_pledged_amount      int64
# country                      object
# country_displayable_name     object
# created_at                    int64
# creator                      object
# currency                     object
# currency_symbol              object
# currency_trailing_code         bool
# current_currency             object
# deadline                      int64
# disable_communication          bool
# friends                      object
# fx_rate                     float64
# goal                        float64
# id                            int64
# is_backing                   object
# is_starrable                   bool
# is_starred                   object
# launched_at                   int64
# location                     object
# name                         object
# permissions                  object
# photo                        object
# pledged                     float64
# profile                      object
# slug                         object
# source_url                   object
# spotlight                      bool
# staff_pick                     bool
# state                        object
# state_changed_at              int64
# static_usd_rate             float64
# unread_messages_count       float64
# unseen_activity_count       float64
# urls                         object
# usd_pledged                 float64
# usd_type                     object
# dtype: object

# %%
# Converting all strings to lowercase for easier comparison with the BGG dataset later on
frame = frame.applymap(lambda s:s.lower() if type(s) == str else s)

# %%
# Saving new CSV for the model
df.to_csv("2018_2019_KS_cleaned.csv")

# %%
BGGdf = pd.read_csv('2018_06_BGG_cleaned.csv')

# %%
KSBGGdf = pd.merge(frame, BGGdf, on='name', how='outer', indicator = True)

# %%
KSBGGdf.to_csv("KSBGGdf.csv")

# %%
testing = pd.read_csv('KSBGGdf.csv', engine = 'python')

# %%
testing
# Out:
#        Unnamed: 0  Unnamed: 0_x  backers_count  \
# 0               0       12261.0           62.0
# 1               1       12283.0         1126.0
# 2               2       12304.0          189.0
# 3               3       12316.0           86.0
# 4               4       12322.0          413.0
# ...           ...           ...            ...
# 17060       17060           NaN            NaN
# 17061       17061           NaN            NaN
# 17062       17062           NaN            NaN
# 17063       17063           NaN            NaN
# 17064       17064           NaN            NaN
#
#                                                    blurb  \
# 0      help "uplift" some of the great 6mm scale mini...
# 1      demonwars: reformation is an old-school tablet...
# 2      the popular yushino iphone, android, facebook ...
# 3      hello sweet potatoÃ¢â€žÂ¢Ã¢â‚¬â€�a fun way to ...
# 4      fully cooperative tile-based exploration and r...
# ...                                                  ...
# 17060                                                NaN
# 17061                                                NaN
# 17062                                                NaN
# 17063                                                NaN
# 17064                                                NaN
#
#                                               category_x  \
# 0      {"id":34,"name":"tabletop games","slug":"games...
# 1      {"id":34,"name":"tabletop games","slug":"games...
# 2      {"id":34,"name":"tabletop games","slug":"games...
# 3      {"id":34,"name":"tabletop games","slug":"games...
# 4      {"id":34,"name":"tabletop games","slug":"games...
# ...                                                  ...
# 17060                                                NaN
# 17061                                                NaN
# 17062                                                NaN
# 17063                                                NaN
# 17064                                                NaN
#
#        converted_pledged_amount country country_displayable_name  \
# 0                        4835.0      us                      NaN
# 1                       88245.0      us                      NaN
# 2                       10460.0      us                      NaN
# 3                       15655.0      us                      NaN
# 4                       32105.0      us                      NaN
# ...                         ...     ...                      ...
# 17060                       NaN     NaN                      NaN
# 17061                       NaN     NaN                      NaN
# 17062                       NaN     NaN                      NaN
# 17063                       NaN     NaN                      NaN
# 17064                       NaN     NaN                      NaN
#
#          created_at                                            creator  ...  \
# 0      1.396471e+09  {"id":1101721577,"name":"darkest star games","...  ...
# 1      1.374081e+09  {"id":1565757521,"name":"r.a. salvatore","slug...  ...
# 2      1.378405e+09  {"id":729844106,"name":"yushino","is_registere...  ...
# 3      1.376051e+09  {"id":84294323,"name":"barbara movius","is_reg...  ...
# 4      1.392517e+09  {"id":1299225771,"name":"dave schroeder","is_r...  ...
# ...             ...                                                ...  ...
# 17060           NaN                                                NaN  ...
# 17061           NaN                                                NaN  ...
# 17062           NaN                                                NaN  ...
# 17063           NaN                                                NaN  ...
# 17064           NaN                                                NaN  ...
#
#       geek_rating num_votes  \
# 0             NaN       NaN
# 1             NaN       NaN
# 2             NaN       NaN
# 3             NaN       NaN
# 4             NaN       NaN
# ...           ...       ...
# 17060     5.64032     456.0
# 17061     5.64030     277.0
# 17062     5.64026     146.0
# 17063     5.64024     257.0
# 17064     5.64024     283.0
#
#                                                image_url   age  \
# 0                                                    NaN   NaN
# 1                                                    NaN   NaN
# 2                                                    NaN   NaN
# 3                                                    NaN   NaN
# 4                                                    NaN   NaN
# ...                                                  ...   ...
# 17060  https://cf.geekdo-images.com/original/img/pbmq...   8.0
# 17061  https://cf.geekdo-images.com/original/img/ea2o...  10.0
# 17062  https://cf.geekdo-images.com/original/img/2ext...  13.0
# 17063  https://cf.geekdo-images.com/original/img/enqf...  14.0
# 17064  https://cf.geekdo-images.com/original/img/7is6...  13.0
#
#                                                 mechanic  owned  \
# 0                                                    NaN    NaN
# 1                                                    NaN    NaN
# 2                                                    NaN    NaN
# 3                                                    NaN    NaN
# 4                                                    NaN    NaN
# ...                                                  ...    ...
# 17060                     area enclosure, tile placement  561.0
# 17061  action point allowance system, dice rolling, v...  825.0
# 17062               auction/bidding, pick-up and deliver  440.0
# 17063    point to point movement, variable player powers  659.0
# 17064                        card drafting, dice rolling  629.0
#
#                                               category_y  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 17060                        city building, print & play
# 17061  ancient, collectible components, dice, fantasy...
# 17062                                   economic, trains
# 17063                             age of reason, wargame
# 17064                                            fantasy
#
#                                                 designer  weight      _merge
# 0                                                    NaN     NaN   left_only
# 1                                                    NaN     NaN   left_only
# 2                                                    NaN     NaN   left_only
# 3                                                    NaN     NaN   left_only
# 4                                                    NaN     NaN   left_only
# ...                                                  ...     ...         ...
# 17060                       tobias goslar, roland goslar  1.9074  right_only
# 17061  tyler bielman, jonathon loucks, ethan pasterna...  2.3750  right_only
# 17062                        john bohrer, martin wallace  2.6250  right_only
# 17063                                  robert g. markham  2.4359  right_only
# 17064                                  robert j. hudecek  1.6000  right_only
#
# [17065 rows x 200 columns]

# %%
testing2 = testing.loc[testing['_merge'] == 'both']

# %%
testing2
# Out:
#        Unnamed: 0  Unnamed: 0_x  backers_count  \
# 6               6       12363.0          374.0
# 80             80       14156.0         1309.0
# 105           105       15473.0         5258.0
# 179           179       18580.0         1043.0
# 186           186       19366.0          652.0
# ...           ...           ...            ...
# 9799         9799      175207.0            6.0
# 10161       10161      229329.0          560.0
# 11466       11466      693901.0         2484.0
# 11470       11470      694370.0          498.0
# 11774       11774     1055335.0         1490.0
#
#                                                    blurb  \
# 6      the hidden identity, bluffing, and deduction g...
# 80     enjoy the complete thebes experience with the ...
# 105    cooperative zombie survival game with 71 great...
# 179    a semi-cooperative, mostly-competitive, strate...
# 186    shields are down to 40%, hyper drive is offlin...
# ...                                                  ...
# 9799   maquis is an easy roleplaying card game ambien...
# 10161  a new, deluxe version of the board game classi...
# 11466          a small box solo game of harvesting fruit
# 11470  the classic card game of trains and passengers...
# 11774  strip mine titan in this exciting eurogame fea...
#
#                                               category_x  \
# 6      {"id":34,"name":"tabletop games","slug":"games...
# 80     {"id":34,"name":"tabletop games","slug":"games...
# 105    {"id":34,"name":"tabletop games","slug":"games...
# 179    {"id":34,"name":"tabletop games","slug":"games...
# 186    {"id":34,"name":"tabletop games","slug":"games...
# ...                                                  ...
# 9799   {"id":34,"name":"tabletop games","slug":"games...
# 10161  {"id":34,"name":"tabletop games","slug":"games...
# 11466  {"id":34,"name":"tabletop games","slug":"games...
# 11470  {"id":34,"name":"tabletop games","slug":"games...
# 11774  {"id":34,"name":"tabletop games","slug":"games...
#
#        converted_pledged_amount country country_displayable_name  \
# 6                        5864.0      us                      NaN
# 80                      90554.0      us                      NaN
# 105                    781597.0      us                      NaN
# 179                     76649.0      us                      NaN
# 186                     48642.0      us                      NaN
# ...                         ...     ...                      ...
# 9799                      106.0      es                      NaN
# 10161                   63725.0      us        the united states
# 11466                   40374.0      us        the united states
# 11470                   16105.0      us        the united states
# 11774                  135847.0      fr                   france
#
#          created_at                                            creator  ...  \
# 6      1.387479e+09  {"id":1026360181,"name":"overworld games","slu...  ...
# 80     1.395938e+09  {"id":1016374822,"name":"queen games","is_regi...  ...
# 105    1.333298e+09  {"id":1134494596,"name":"cmon","slug":"cmon","...  ...
# 179    1.371518e+09  {"id":1234521854,"name":"dice hate me games","...  ...
# 186    1.338853e+09  {"id":996972475,"name":"break from reality gam...  ...
# ...             ...                                                ...  ...
# 9799   1.553954e+09  {"id":413001094,"name":"producciones repÃ£Âºbl...  ...
# 10161  1.538116e+09  {"id":1942747115,"name":"columbia games","slug...  ...
# 11466  1.565369e+09  {"id":771559871,"name":"side room games","slug...  ...
# 11470  1.572451e+09  {"id":781219801,"name":"ray wehrs","is_registe...  ...
# 11774  1.571065e+09  {"id":148661905,"name":"holy grail games","slu...  ...
#
#       geek_rating num_votes  \
# 6         6.32972    2399.0
# 80        6.95286    8170.0
# 105       7.01424   12902.0
# 179       6.23443    1471.0
# 186       5.67731     247.0
# ...           ...       ...
# 9799      5.81601     284.0
# 10161     7.04238    3509.0
# 11466     5.79081     634.0
# 11470     5.71460     551.0
# 11774     6.55390    3692.0
#
#                                                image_url   age  \
# 6      https://cf.geekdo-images.com/original/img/zubz...  12.0
# 80     https://cf.geekdo-images.com/original/img/clwm...   8.0
# 105    https://cf.geekdo-images.com/original/img/fwnb...  13.0
# 179    https://cf.geekdo-images.com/original/img/jdmq...  10.0
# 186    https://cf.geekdo-images.com/original/img/7aq1...  10.0
# ...                                                  ...   ...
# 9799   https://cf.geekdo-images.com/original/img/reqy...   0.0
# 10161  https://cf.geekdo-images.com/original/img/l-kx...  12.0
# 11466  https://cf.geekdo-images.com/original/img/zzxo...   3.0
# 11470  https://cf.geekdo-images.com/original/img/pdz9...  10.0
# 11774  https://cf.geekdo-images.com/original/img/zuws...  12.0
#
#                                                 mechanic    owned  \
# 6      hand management, memory, partnerships, player ...   4023.0
# 80                   point to point movement, time track   9587.0
# 105    action point allowance system, co-operative pl...  18657.0
# 179    dice rolling, modular board, paper-and-pencil,...   2867.0
# 186    co-operative play, modular board, pick-up and ...    589.0
# ...                                                  ...      ...
# 9799                                    worker placement    416.0
# 10161  area movement, campaign / battle card driven, ...   4466.0
# 11466                    co-operative play, dice rolling   1229.0
# 11470  betting/wagering, commodity speculation, hand ...    761.0
# 11774  dice rolling, player elimination, roll / spin ...   5204.0
#
#                                               category_y  \
# 6      bluffing, card game, deduction, party game, sp...
# 80                          ancient, exploration, travel
# 105                          horror, miniatures, zombies
# 179                                                 dice
# 186                           real-time, science fiction
# ...                                                  ...
# 9799                          print & play, world war ii
# 10161                                  medieval, wargame
# 11466                              children's game, dice
# 11470                                  card game, trains
# 11774                                  fantasy, fighting
#
#                                                 designer  weight  _merge
# 6                            brian henk, clayton skancke  1.2391    both
# 80                                           peter prinz  2.1640    both
# 105    raphaÃ£Â«l guiton, jean-baptiste lullien, nico...  2.5640    both
# 179                                     t. c. petty, iii  1.7391    both
# 186                                        alex barbieri  2.6000    both
# ...                                                  ...     ...     ...
# 9799                                        jake staines  2.0435    both
# 10161                        tom dalgliesh, jerry taylor  2.9826    both
# 11466                            anneliese farkaschovsky  1.0469    both
# 11470                                      chris bayliss  1.5479    both
# 11774             jason b. mcallister, david a. trampier  3.4576    both
#
# [171 rows x 200 columns]

# %%
testing2.to_csv("testing2.csv")
