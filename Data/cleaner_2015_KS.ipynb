# %% [markdown]
# ## 2015_KS_cleaner_code

# %% [markdown]
# Due to the large size of the Kickstarter (KS) Datasets (up to 564 csv files / 10.3gb per year) I wrote some code to process the KS data one year at a time. This code will process KS data from 2015.

# %% [markdown]
# ### IF YOU ARE READING THIS FROM GITHUB PLEASE NOTE THAT RUNNING CELL [2] WILL NOT WORK UNTIL I FIND A WAY TO HOST THE ~28.4 GIGABYTES OF KS DATASETS

# %%
# Imports
import numpy as np
import pandas as pd
import glob #glob allows us to easily concatenate multiple .csvs in one folder

# %%
# Concatenating 2015 KS data with glob
path = r'D:\DSI-D\projects\project_6\Data\2015_KS'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
# EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202272 entries, 0 to 202271
# Data columns (total 27 columns):
# backers_count             202272 non-null int64
# blurb                     202260 non-null object
# category                  202272 non-null object
# country                   202272 non-null object
# created_at                202272 non-null int64
# creator                   202272 non-null object
# currency                  202272 non-null object
# currency_symbol           202272 non-null object
# currency_trailing_code    202272 non-null bool
# deadline                  202272 non-null int64
# disable_communication     202272 non-null bool
# goal                      202272 non-null float64
# id                        202272 non-null int64
# launched_at               202272 non-null int64
# location                  201227 non-null object
# name                      202269 non-null object
# photo                     202272 non-null object
# ...

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0             94  Help a rural Wisconsin community bring a uniqu...
# 1             63  Miko Kuro's Midnight Tea is collaborative art ...
# 2             12  headphone(s) is a collaboration between artist...
# 3           2040  It might be the worlds first ever podcast rele...
# 4             20  Black Hawk Middle School students and staff wi...
#
#                                             category country  created_at  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...      US  1407704490
# 1  {"urls":{"web":{"discover":"http://www.kicksta...      US  1350299650
# 2  {"urls":{"web":{"discover":"http://www.kicksta...      US  1412819907
# 3  {"urls":{"web":{"discover":"http://www.kicksta...      US  1323199356
# 4  {"urls":{"web":{"discover":"http://www.kicksta...      US  1330617307
#
#                                              creator currency currency_symbol  \
# ...

# %%
df.tail()
# Out:
#         backers_count                                              blurb  \
# 202267            107  A comedy about a lovable loser trying to get o...
# 202268             18  A war drama that follows a little Afghani girl...
# 202269             39  A comedy about a team of filmmakers who must f...
# 202270             53  The Adventures of Dex Dixon: Paranormal Dick! ...
# 202271             38  THE PROPERTY is a feature film about idealists...
#
#                                                  category country  created_at  \
# 202267  {"urls":{"web":{"discover":"http://www.kicksta...      US  1326832716
# 202268  {"urls":{"web":{"discover":"http://www.kicksta...      US  1285707043
# 202269  {"urls":{"web":{"discover":"http://www.kicksta...      US  1300297100
# 202270  {"urls":{"web":{"discover":"http://www.kicksta...      US  1308777540
# 202271  {"urls":{"web":{"discover":"http://www.kicksta...      US  1311369868
#
# ...

# %%
# Dropping duplicates to cut down on rows
df.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 168725 entries, 0 to 202247
# Data columns (total 27 columns):
# backers_count             168725 non-null int64
# blurb                     168718 non-null object
# category                  168725 non-null object
# country                   168725 non-null object
# created_at                168725 non-null int64
# creator                   168725 non-null object
# currency                  168725 non-null object
# currency_symbol           168725 non-null object
# currency_trailing_code    168725 non-null bool
# deadline                  168725 non-null int64
# disable_communication     168725 non-null bool
# goal                      168725 non-null float64
# id                        168725 non-null int64
# launched_at               168725 non-null int64
# location                  167819 non-null object
# name                      168724 non-null object
# photo                     168725 non-null object
# ...

# %%
# Creating a dataframe of only boardgame KS projects
df = df.loc[df['category'] == '{"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}},"color":51627,"parent_id":12,"name":"Tabletop Games","id":34,"position":6,"slug":"games/tabletop games"}']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4112 entries, 40727 to 96173
# Data columns (total 27 columns):
# backers_count             4112 non-null int64
# blurb                     4112 non-null object
# category                  4112 non-null object
# country                   4112 non-null object
# created_at                4112 non-null int64
# creator                   4112 non-null object
# currency                  4112 non-null object
# currency_symbol           4112 non-null object
# currency_trailing_code    4112 non-null bool
# deadline                  4112 non-null int64
# disable_communication     4112 non-null bool
# goal                      4112 non-null float64
# id                        4112 non-null int64
# launched_at               4112 non-null int64
# location                  4107 non-null object
# name                      4112 non-null object
# photo                     4112 non-null object
# pledged                   4112 non-null float64
# ...

# %%
# Saving the cleaned 2015 .csv
df.to_csv("KS_data/2015_KS_cleaned.csv", index = False)
