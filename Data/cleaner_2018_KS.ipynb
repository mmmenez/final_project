# %% [markdown]
# ## 2018_KS_cleaner_code

# %% [markdown]
# Due to the large size of the Kickstarter (KS) Datasets (up to 564 csv files / 10.3gb per year) I wrote some code to process the KS data one year at a time. This code will process KS data from 2018.

# %% [markdown]
# ### IF YOU ARE READING THIS FROM GITHUB PLEASE NOTE THAT RUNNING CELL [2] WILL NOT WORK UNTIL I FIND A WAY TO HOST THE ~28.4 GIGABYTES OF KS DATASETS

# %%
# imports
import numpy as np
import pandas as pd
import glob #glob allows us to easily concatenate multiple .csvs in one folder

# %%
# Concatenating 2018 KS data with glob
path = r'D:\DSI-D\projects\project_6\Data\2018_KS'
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   # This is added back by InteractiveShellApp.init_path()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2222894 entries, 0 to 2222893
# Data columns (total 37 columns):
# backers_count               int64
# blurb                       object
# category                    object
# converted_pledged_amount    int64
# country                     object
# created_at                  int64
# creator                     object
# currency                    object
# currency_symbol             object
# currency_trailing_code      bool
# current_currency            object
# deadline                    int64
# disable_communication       bool
# friends                     object
# fx_rate                     float64
# goal                        float64
# id                          int64
# is_backing                  object
# is_starrable                bool
# is_starred                  object
# launched_at                 int64
# location                    object
# name                        object
# permissions                 object
# photo                       object
# pledged                     float64
# profile                     object
# slug                        object
# source_url                  object
# spotlight                   bool
# staff_pick                  bool
# state                       object
# state_changed_at            int64
# static_usd_rate             float64
# urls                        object
# usd_pledged                 float64
# usd_type                    object
# dtypes: bool(5), float64(5), int64(7), object(20)
# memory usage: 553.3+ MB

# %%
df.head()
# Out:
#    backers_count                                              blurb  \
# 0              1  Monsters, Fantasy, Illusion, Delusion, and a h...
# 1             37  Nano Art will make and market customized piece...
# 2             81  Video and audio coverage of the MUTEK festival...
# 3             95              Finally, A Storyboard App Done Right!
# 4             10  If you like books and bookmarks, stick these s...
#
#                                             category  \
# 0  {"urls":{"web":{"discover":"http://www.kicksta...
# 1  {"urls":{"web":{"discover":"http://www.kicksta...
# 2  {"urls":{"web":{"discover":"http://www.kicksta...
# 3  {"urls":{"web":{"discover":"http://www.kicksta...
# 4  {"urls":{"web":{"discover":"http://www.kicksta...
#
#    converted_pledged_amount country  created_at  \
# 0                        20      US  1332493397
# 1                      1974      US  1332823105
# 2                      4845      US  1331241234
# 3                      2948      US  1332350493
# 4                       522      US  1333768943
#
#                                              creator currency currency_symbol  \
# 0  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 1  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 2  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 3  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
# 4  {"urls":{"web":{"user":"https://www.kickstarte...      USD               $
#
#    currency_trailing_code  ...  \
# 0                    True  ...
# 1                    True  ...
# 2                    True  ...
# 3                    True  ...
# 4                    True  ...
#
#                                                 slug  \
# 0                  represent-the-strange-and-unusual
# 1                                  nano-art-reloaded
# 2             mutek-festival-virtual-festival-studio
# 3  sketchpad-pro-a-filmmakers-storyboard-for-the-...
# 4                          apples-and-lemons-reviews
#
#                                           source_url  spotlight staff_pick  \
# 0  https://www.kickstarter.com/discover/categorie...      False      False
# 1  https://www.kickstarter.com/discover/categorie...      False       True
# 2  https://www.kickstarter.com/discover/categorie...      False       True
# 3  https://www.kickstarter.com/discover/categorie...      False      False
# 4  https://www.kickstarter.com/discover/categorie...      False      False
#
#     state  state_changed_at  static_usd_rate  \
# 0  failed        1336447572              1.0
# 1  failed        1337287105              1.0
# 2  failed        1337227140              1.0
# 3  failed        1338448438              1.0
# 4  failed        1338609542              1.0
#
#                                                 urls  usd_pledged  usd_type
# 0  {"web":{"project":"https://www.kickstarter.com...         20.0  domestic
# 1  {"web":{"project":"https://www.kickstarter.com...       1974.0  domestic
# 2  {"web":{"project":"https://www.kickstarter.com...       4845.0  domestic
# 3  {"web":{"project":"https://www.kickstarter.com...       2948.0  domestic
# 4  {"web":{"project":"https://www.kickstarter.com...        522.0  domestic
#
# [5 rows x 37 columns]

# %%
df.tail()
# Out:
#          backers_count                                              blurb  \
# 2222889             25  Turning crowdfunding and crowdsourcing into an...
# 2222890             35  Please donate if you like what you hear and ke...
# 2222891              2  My hydroponic & aquaponic farm homemade. Growi...
# 2222892              3  Working with survivors of violence using art a...
# 2222893              4  A multiplayer browser remake of the classic Bo...
#
#                                                   category  \
# 2222889  {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 2222890  {"id":40,"name":"Indie Rock","slug":"music/ind...
# 2222891  {"id":309,"name":"Farms","slug":"food/farms","...
# 2222892  {"id":54,"name":"Mixed Media","slug":"art/mixe...
# 2222893  {"id":35,"name":"Video Games","slug":"games/vi...
#
#          converted_pledged_amount country  created_at  \
# 2222889                      1783      DE  1435130528
# 2222890                      3665      US  1331331250
# 2222891                       101      US  1416035465
# 2222892                        75      US  1431103642
# 2222893                        71      US  1541101775
#
#                                                    creator currency  \
# 2222889  {"id":1147755614,"name":"Theo Ligthart","slug"...      EUR
# 2222890  {"id":548206958,"name":"Sierra","is_registered...      USD
# 2222891  {"id":1903527888,"name":"Abel Shiver (deleted)...      USD
# 2222892  {"id":874706789,"name":"Susan E Meyers","slug"...      USD
# 2222893  {"id":799038862,"name":"WizardWarsIO","slug":"...      USD
#
#         currency_symbol  currency_trailing_code  ...  \
# 2222889               €                   False  ...
# 2222890               $                    True  ...
# 2222891               $                    True  ...
# 2222892               $                    True  ...
# 2222893               $                    True  ...
#
#                                                       slug  \
# 2222889                                 ligtharts-comeback
# 2222890      sierra-west-hold-your-fire-ep-keep-it-burning
# 2222891             hydroponic-and-aquaponic-homemade-farm
# 2222892                                     healing-abroad
# 2222893  diamonddelightio-a-multiplayer-puzzle-arcade-game
#
#                                                 source_url  spotlight  \
# 2222889  https://www.kickstarter.com/discover/categorie...      False
# 2222890  https://www.kickstarter.com/discover/categorie...       True
# 2222891  https://www.kickstarter.com/discover/categorie...      False
# 2222892  https://www.kickstarter.com/discover/categorie...      False
# 2222893  https://www.kickstarter.com/discover/categorie...      False
#
#         staff_pick       state  state_changed_at  static_usd_rate  \
# 2222889      False      failed        1438253000         1.101171
# 2222890      False  successful        1338508819         1.000000
# 2222891      False      failed        1416643636         1.000000
# 2222892      False      failed        1438107172         1.000000
# 2222893      False        live        1541380757         1.000000
#
#                                                       urls  usd_pledged  \
# 2222889  {"web":{"project":"https://www.kickstarter.com...  1789.403216
# 2222890  {"web":{"project":"https://www.kickstarter.com...  3665.000000
# 2222891  {"web":{"project":"https://www.kickstarter.com...   101.000000
# 2222892  {"web":{"project":"https://www.kickstarter.com...    75.000000
# 2222893  {"web":{"project":"https://www.kickstarter.com...    71.000000
#
#               usd_type
# 2222889  international
# 2222890  international
# 2222891  international
# 2222892  international
# 2222893  international
#
# [5 rows x 37 columns]

# %%
# Dropping duplicates to reduce the number of rows
df.drop_duplicates(subset="name", keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 239889 entries, 0 to 2222735
# Data columns (total 37 columns):
# backers_count               239889 non-null int64
# blurb                       239881 non-null object
# category                    239889 non-null object
# converted_pledged_amount    239889 non-null int64
# country                     239889 non-null object
# created_at                  239889 non-null int64
# creator                     239889 non-null object
# currency                    239889 non-null object
# currency_symbol             239889 non-null object
# currency_trailing_code      239889 non-null bool
# current_currency            239889 non-null object
# deadline                    239889 non-null int64
# disable_communication       239889 non-null bool
# friends                     1070 non-null object
# fx_rate                     239889 non-null float64
# goal                        239889 non-null float64
# id                          239889 non-null int64
# is_backing                  1070 non-null object
# is_starrable                239889 non-null bool
# is_starred                  1070 non-null object
# launched_at                 239889 non-null int64
# location                    238942 non-null object
# name                        239888 non-null object
# permissions                 1070 non-null object
# photo                       239889 non-null object
# pledged                     239889 non-null float64
# profile                     239889 non-null object
# slug                        239889 non-null object
# source_url                  132995 non-null object
# spotlight                   239889 non-null bool
# staff_pick                  239889 non-null bool
# state                       239889 non-null object
# state_changed_at            239889 non-null int64
# static_usd_rate             239889 non-null float64
# urls                        239889 non-null object
# usd_pledged                 239889 non-null float64
# usd_type                    237671 non-null object
# dtypes: bool(5), float64(5), int64(7), object(20)
# memory usage: 61.5+ MB

# %%
# Nothing out of the ordinary re. the nulls
df.isnull().sum()
# Out:
# backers_count                    0
# blurb                            8
# category                         0
# converted_pledged_amount         0
# country                          0
# created_at                       0
# creator                          0
# currency                         0
# currency_symbol                  0
# currency_trailing_code           0
# current_currency                 0
# deadline                         0
# disable_communication            0
# friends                     238819
# fx_rate                          0
# goal                             0
# id                               0
# is_backing                  238819
# is_starrable                     0
# is_starred                  238819
# launched_at                      0
# location                       947
# name                             1
# permissions                 238819
# photo                            0
# pledged                          0
# profile                          0
# slug                             0
# source_url                  106894
# spotlight                        0
# staff_pick                       0
# state                            0
# state_changed_at                 0
# static_usd_rate                  0
# urls                             0
# usd_pledged                      0
# usd_type                      2218
# dtype: int64

# %%
# Creating a dataframe of only boardgame KS projects
df = df.loc[df['category'] == '{"id":34,"name":"Tabletop Games","slug":"games/tabletop games","position":6,"parent_id":12,"color":51627,"urls":{"web":{"discover":"http://www.kickstarter.com/discover/categories/games/tabletop%20games"}}}']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6356 entries, 12261 to 2220307
# Data columns (total 37 columns):
# backers_count               6356 non-null int64
# blurb                       6356 non-null object
# category                    6356 non-null object
# converted_pledged_amount    6356 non-null int64
# country                     6356 non-null object
# created_at                  6356 non-null int64
# creator                     6356 non-null object
# currency                    6356 non-null object
# currency_symbol             6356 non-null object
# currency_trailing_code      6356 non-null bool
# current_currency            6356 non-null object
# deadline                    6356 non-null int64
# disable_communication       6356 non-null bool
# friends                     300 non-null object
# fx_rate                     6356 non-null float64
# goal                        6356 non-null float64
# id                          6356 non-null int64
# is_backing                  300 non-null object
# is_starrable                6356 non-null bool
# is_starred                  300 non-null object
# launched_at                 6356 non-null int64
# location                    6351 non-null object
# name                        6356 non-null object
# permissions                 300 non-null object
# photo                       6356 non-null object
# pledged                     6356 non-null float64
# profile                     6356 non-null object
# slug                        6356 non-null object
# source_url                  2433 non-null object
# spotlight                   6356 non-null bool
# staff_pick                  6356 non-null bool
# state                       6356 non-null object
# state_changed_at            6356 non-null int64
# static_usd_rate             6356 non-null float64
# urls                        6356 non-null object
# usd_pledged                 6356 non-null float64
# usd_type                    5787 non-null object
# dtypes: bool(5), float64(5), int64(7), object(20)
# memory usage: 1.6+ MB

# %%
# Saving the cleaned 2018.csv
df.to_csv("KS_Data/2018_KS_cleaned.csv", index = False)
